# %%
import numpy as np
sales = np.array([120,340,560,230,150])
products = np.array(["A", "B", "C", "D", "E"])
filtered_products = products[sales>200]
print("products with sales>200:", filtered_products)
# Out:
# products with sales>200: ['B' 'C' 'D']

# %%
import numpy as np
sales = np.array([120,340,560,230,150])
products = np.array(["A", "B", "C", "D", "E"])
print(np.sort(products))
# Out:
# ['A' 'B' 'C' 'D' 'E']

# %%
import numpy as np
sales = np.array([120,340,560,230,150])
products = np.array(["A", "B", "C", "D", "E"])
print(np.average(sales))
# Out:
# 280.0

# %%
import numpy as np
sales = np.array([120,340,560,230,150])
products = np.array(["A", "B", "C", "D", "E"])
print(np.vstack((sales,products)))
# Out:
# [['120' '340' '560' '230' '150']
#  ['A' 'B' 'C' 'D' 'E']]
