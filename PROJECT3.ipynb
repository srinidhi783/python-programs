# %%
name = input("Enter student name: ")
print("Welcome", name)
# Out:
# Enter student name:  saisrinidhi
# Welcome saisrinidhi

# %%
name = input("Enter student name: ")

sub1 = int(input("Enter marks of Subject1: "))
sub2 = int(input("Enter marks of Subject2: "))
sub3 = int(input("Enter marks of Subject3: "))

print("Student Name:", name)
print("Subject 1:", sub1)
print("Subject 2:", sub2)
print("Subject 3:", sub3)
# Out:
# Enter student name:  saisrinidhi
# Enter marks of Subject1:  88
# Enter marks of Subject2:  89
# Enter marks of Subject3:  78
# Student Name: saisrinidhi
# Subject 1: 88
# Subject 2: 89
# Subject 3: 78

# %%
total = sub1 + sub2 + sub3
percentage = total / 3

print("Total Marks:", total)
print("Percentage:", percentage)
# Out:
# Total Marks: 255
# Percentage: 85.0

# %%
if percentage >= 90:
    grade = "A+"
elif percentage >= 80:
    grade = "A"
elif percentage >= 70:
    grade = "B"
elif percentage >= 60:
    grade = "C"
elif percentage >= 50:
    grade = "D"
else:
    grade = "Fail"

# %%
print("\n----- STUDENT REPORT -----")
print("Student Name :", name)
print("Total Marks  :", total)
print("Percentage   :", percentage)
print("Grade        :", grade)
print("Status       :", status)
# Out:
# ----- STUDENT REPORT -----
# Student Name : saisrinidhi
# Total Marks  : 255
# Percentage   : 85.0
# Grade        : A
# Status       : PASS
