# %%
16/06/2026

# %%
import numpy as np
marks=np.array([30,40,50,60,80])
print(np.min(marks))
# Out:
# 30

# %%
import numpy as np
marks=np.array([30,40,50,60,80])
print(np.max(marks))
# Out:
# 80

# %%
import numpy as np
marks=np.array([30,40,50,60,80])
print(np.sum(marks))
# Out:
# 260

# %%
import numpy as np
numbers = [10,20,30,40]
average = sum(numbers) / len(numbers)
print("Average =",average)
# Out:
# Average = 25.0

# %%
import numpy as np
numbers = [30,40,50,60,80]
average = sum(numbers) / len(numbers)
print("Average =",average)
# Out:
# Average = 52.0

# %%
import numpy as np
marks=np.array([40,35,60,80,80])
print(np.mean(marks))
# Out:
# 59.0
