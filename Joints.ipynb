# %%
import pandas as pd
data={"Name":["mani","mamu","baby","sanju","kanni","kutty","dhanvi"],
      "Age":[33,40,51,20,15,25,35],
      "City":["knr","hyd","pdpl","bnr","sultnbd","gdk","mncl"]
     }
details=pd.DataFrame(data)
print(details.head())
print(details.tail())
print(details.sample(2))
print(details.info())
print(details.describe())
print(details.loc[0])
print(details.loc[[0,1,2]])
# Out:
#     Name  Age     City
# 0   mani   33      knr
# 1   mamu   40      hyd
# 2   baby   51     pdpl
# 3  sanju   20      bnr
# 4  kanni   15  sultnbd
#      Name  Age     City
# 2    baby   51     pdpl
# 3   sanju   20      bnr
# 4   kanni   15  sultnbd
# 5   kutty   25      gdk
# 6  dhanvi   35     mncl
#    Name  Age  City
# 2  baby   51  pdpl
# 1  mamu   40   hyd
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Age     7 non-null      int64
#  2   City    7 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 300.0+ bytes
# None
#              Age
# count   7.000000
# mean   31.285714
# std    12.338480
# min    15.000000
# 25%    22.500000
# 50%    33.000000
# 75%    37.500000
# max    51.000000
# Name    mani
# Age       33
# City     knr
# Name: 0, dtype: object
#    Name  Age  City
# ...

# %%
import pandas as pd
data={"Name":["mani","kanni","kutty","dhanvi"],
      "Age":[33,40,51,20,],
      "City":["knr","hyd","pdpl","bnr"]
     }
details=pd.DataFrame(data)
print(details[details.Age>31]),(details[details.Age<29])
print(details)
details["Grade"]=["A","B","C","D"]
print(details)
details["Age"]=details["Age"] +3
print(details)
# Out:
#     Name  Age  City
# 0   mani   33   knr
# 1  kanni   40   hyd
# 2  kutty   51  pdpl
#      Name  Age  City
# 0    mani   33   knr
# 1   kanni   40   hyd
# 2   kutty   51  pdpl
# 3  dhanvi   20   bnr
#      Name  Age  City Grade
# 0    mani   33   knr     A
# 1   kanni   40   hyd     B
# 2   kutty   51  pdpl     C
# 3  dhanvi   20   bnr     D
#      Name  Age  City Grade
# 0    mani   36   knr     A
# 1   kanni   43   hyd     B
# 2   kutty   54  pdpl     C
# 3  dhanvi   23   bnr     D

# %%
dataJoin=pd.DataFrame({
         "ID":[1,2,3],
          "NAME":["harika","kutty","kanni"]})
print(dataJoin)
# Out:
#    ID    NAME
# 0   1  harika
# 1   2   kutty
# 2   3   kanni

# %%
dataJoin2=pd.DataFrame({
          "ID":[1,2,3],
           "MARKS":[90,80,70]})
print(dataJoin2)
# Out:
#    ID  MARKS
# 0   1     90
# 1   2     80
# 2   3     70

# %%
Result=pd.merge(dataJoin,dataJoin2,on="ID")
print(Result)
# Out:
#    ID    NAME  MARKS
# 0   1  harika     90
# 1   2   kutty     80
# 2   3   kanni     70
