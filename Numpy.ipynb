# %%
try:
    num = input("Enter your name")
except NameError:
    print("write characters only")
# Out:
# Enter your name srinidhi

# %%
import numpy as np
arr = np.array([10,20,30,40])
print(arr)
# Out:
# [10 20 30 40]

# %%
arr = np.array([[10,20], [20,30], [40,8]])
print(arr)
# Out:
# [[10 20]
#  [20 30]
#  [40  8]]

# %%
import numpy as np
arr = np.array([10,20,30,40,50])
print(arr)
print(arr*2)
# Out:
# [10 20 30 40 50]
# [ 20  40  60  80 100]

# %%
import numpy as np
a = np.array([10,20,30,40])
b = np.array([1,2,3,4])
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# [11 22 33 44]
# [ 9 18 27 36]
# [ 10  40  90 160]
# [10. 10. 10. 10.]

# %%
abc = np.array([10,20,30,40])
print(np.max(abc))
# Out:
# 40

# %%
def count(n):
    if n==0:
       return
    print(n)
    count(n-1)
count(5)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
for i in range(5):
    print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello

# %%
def fact(n):
    if (n==1):
         return 1
        
    return n*fact(n-1)
print(fact(5))
# Out:
# 120

# %%
def square(x):
    return x*x
print(square(6))
# Out:
# 36

# %%
square = lambda x:x*x
print(square(3))
# Out:
# 9

# %%
mul = lambda a,b:b*a
print(mul(5,2))
# Out:
# 10

# %%
check = lambda num:"Even" if num%2==0 else "Odd"
print(check(10))
# Out:
# Even

# %%
check = lambda num:"Even" if num%2==0 else "Odd"
print(check(7))
# Out:
# Odd

# %%
student=[("Ram",80), ("ravi",75), ("mahesh",35)]
result=sorted(student, key=lambda x:x[1])
print(result)
# Out:
# [('mahesh', 35), ('ravi', 75), ('Ram', 80)]
