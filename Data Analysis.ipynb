# %%
import re
text="python is easy"
result=re.search("python", text)
print(result)
# Out:
# <re.Match object; span=(0, 6), match='python'>

# %%
import re
text="i have 10 books 20 pens"
result=re.findall(r"\d", text)
print(result)
# Out:
# ['1', '0', '2', '0']

# %%
import re
text="i have 10 books 20 pens"
result=re.findall(r"\d+", text)
print(result)
# Out:
# ['10', '20']

# %%
import re
text="python programming"
result=re.match("python",text)
print(result.group())
# Out:
# python

# %%
import re
text="python,java,css"
result=re.split(",",text)
print(result)
# Out:
# ['python', 'java', 'css']

# %%
import re
text="python programming"
result=re.sub("python","java",text)
print(result)
# Out:
# java programming

# %%
import re
text="my age is 20"
result=re.search("\d+",text)
print(result)
# Out:
# <re.Match object; span=(10, 12), match='20'>

# %%
import re
text="my age is 20"
result=re.findall(r"\d+",text)
print(result)
# Out:
# ['20']

# %%
import re 
email = "xyz@gmail.com"
pattern=r'^[a-zA-Z0-9]+@[a-zA]+\.[a-zA]+$'
if re.match(pattern,email):
    print("valid")
else:
    print("Invalid")
# Out:
# valid

# %%
import numpy as np
arr=np.array([10,20,30,40,50])
print(arr[[1,3]])
# Out:
# [20 40]

# %%
arr=np.array([10,20,30,40,50])
print(arr[arr>25])
# Out:
# [30 40 50]

# %%
import numpy as np
marks = np.array([30,50,60,80])
print(marks[marks>50])
# Out:
# [60 80]

# %%
import numpy as np
arr=np.array([[10,20],[30,40],[40,50]])
for row in arr:
    print(row)
# Out:
# [10 20]
# [30 40]
# [40 50]

# %%
for i in np.nditer(arr):
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 40
# 50

# %%
import numpy as np
a = "srinidhi"
b = "goud"
c = (a+b)
print(c)
# Out:
# srinidhigoud

# %%
import numpy as np
arr=np.array([10,20,30,40,50])
x=np.where(arr==20)
print(x)
# Out:
# (array([1]),)

# %%
import numpy as np
arr=np.array([10,20,30,40,50])
x=np.sort(arr==10)
print(x)
# Out:
# [False False False False  True]

# %%
import numpy as np
a=np.array([1,2,3,4])
b=np.array([10,20,30,40])
c=(a+b)
print(c)
# Out:
# [11 22 33 44]

# %%
import numpy as np
marks=np.array([40,35,60,80,75])
result=list(filter(lambda marks:marks%2==0,marks))
print(marks[marks>=45])
# Out:
# [60 80 75]
