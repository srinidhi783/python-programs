# %%
import pandas as pd
i=pd.Series([100,200,300])
print(i)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
ci=pd.Series([100,200,300,400])
print(ci)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
