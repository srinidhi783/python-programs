# %%
import pandas as pd
marks=pd.Series([10,40,80,55,67])
mark=pd.Series()
print(marks)
print(mark)
print(marks[1])
# Out:
# 0    10
# 1    40
# 2    80
# 3    55
# 4    67
# dtype: int64
# Series([], dtype: object)
# 40

# %%
t=pd.Series((10,20,30))
print(t)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
student_name=pd.Series(["nidhi","kanni","kutty"])
print(student_name)
# Out:
# 0    nidhi
# 1    kanni
# 2    kutty
# dtype: object

# %%
student={ "srinidhi":20,
          "harika":27
        }
s=pd.Series(student)
print(s)
# Out:
# srinidhi    20
# harika      27
# dtype: int64

# %%
i=pd.Series([100,200,300])
print(i)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
ci=pd.Series([100,200,300,400])
print(ci)
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64

# %%
ci=pd.Series([100,200,300],
             index=["a","b","c"])
print(ci["b"])
print(ci[["a","c"]])
print(ci.index)
print(ci.values)
print(ci.dtype)
print(ci.size)
# Out:
# 200
# a    100
# c    300
# dtype: int64
# Index(['a', 'b', 'c'], dtype='object')
# [100 200 300]
# int64
# 3

# %%
s=pd.Series([10,20,30,40])
print(s.sum())
print(s.max())
print(s.min())
print(s.mean())
print(s[s>=35])
# Out:
# 100
# 40
# 10
# 25.0
# 3    40
# dtype: int64

# %%
b=pd.Series([10,20,30,40,50])
print([b>30])
# Out:
# [0    False
# 1    False
# 2    False
# 3     True
# 4     True
# dtype: bool]

# %%
import numpy as np
import pandas as pd
s=pd.Series([10,20,30,np.nan,40,np.nan])
print(s)
print(s.isnull().sum())
print(s.fillna(0))
print(s.dropna())
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3     NaN
# 4    40.0
# 5     NaN
# dtype: float64
# 2
# 0    10.0
# 1    20.0
# 2    30.0
# 3     0.0
# 4    40.0
# 5     0.0
# dtype: float64
# 0    10.0
# 1    20.0
# 2    30.0
# 4    40.0
# dtype: float64

# %%
names=pd.Series(["srinidhi","dhanvika","dhruvika","harika"])
print(names)
print(names.str.upper())
# Out:
# 0    srinidhi
# 1    dhanvika
# 2    dhruvika
# 3      harika
# dtype: object
# 0    SRINIDHI
# 1    DHANVIKA
# 2    DHRUVIKA
# 3      HARIKA
# dtype: object

# %%
s=pd.Series([10,20,86,98,3,4,5])
print(s.sort_values())
# Out:
# 4     3
# 5     4
# 6     5
# 0    10
# 1    20
# 2    86
# 3    98
# dtype: int64

# %%
s=pd.Series([10,20,86,98,3,4,5,30,20,20,86,3])
print(s.sort_values(ascending=False))
print(s.unique())
print(s.value_counts())
# Out:
# 3     98
# 2     86
# 10    86
# 7     30
# 1     20
# 8     20
# 9     20
# 0     10
# 6      5
# 5      4
# 4      3
# 11     3
# dtype: int64
# [10 20 86 98  3  4  5 30]
# 20    3
# 86    2
# 3     2
# 10    1
# 98    1
# 4     1
# 5     1
# 30    1
# Name: count, dtype: int64
