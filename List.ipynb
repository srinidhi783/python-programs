# %%
name = ["paint","brush","color"]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# paint
# brush
# color

# %%
name = [5,6,7]
it=iter(name)
print(next(it))
print(next(it))
print(next(it))
# Out:
# 5
# 6
# 7

# %%
def numbers():
    yield 1
    yield 2
    yield 3
gen = numbers()
print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 1
# 2
# 3
