# %%
name=input("Enter the name :")
print("welcome",name)
# Out:
# Enter the name : srinidhi
# welcome srinidhi

# %%
p="python"
print(p[::-1])
# Out:
# nohtyp

# %%
first="srinidhi"
second="goud"
print(first+ "" +second)
# Out:
# srinidhigoud

# %%
name="srinidhi"
 def greet():
    print("Hello", name)
greet()
# Out:
# Hello srinidhi

# %%
def add(a,b,c=0):
    return a+b+c
print(add(10,20))
print(add(10,20,30))
# Out:
# 30
# 60

# %%
def multiple(a,b,c=0):
    return a*b*c
print(multiple(10,20))
print(multiple(10,20,30))
# Out:
# 0
# 6000

# %%
def add(*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
# Out:
# 30
# 60
# 100

# %%
def add(*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
add(10,20,30,40,50)
# Out:
# 30
# 60
# 100
# 150

# %%
def student(*marks):
    print(total(marks))
add(60,80)
add(60,80,100)
add(60,80,100,160)
add(60,80,100,160,180)
add(60,80,100,160,180,200)
# Out:
# 140
# 240
# 400
# 580
# 780
