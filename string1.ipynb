# %%
class car:
    color="Red"
    brand="BMW"

 car1=Car():

 print(car1.color)
 print(car1.brand)
# Out:
#   File <string>:5
#     car1=Car():
#                ^
# IndentationError: unindent does not match any outer indentation level

# %%
class car:
    color = "Red"
    brand = "BMW"

car1 = car()

print(car1.color)
print(car1.brand)
# Out:
# Red
# BMW

# %%
 class student:
     def_init_(self,name,age)
       self.name = name
       self.age = age

 s1 = student(
# Out:
#   Cell In[45], line 3
#     self.name = name
#     ^
# IndentationError: unexpected indent

# %% [markdown]
#  s1 = student("srinidhi",19)
#  print(s1.name)

# %%
 class student:
     def __init__(self,name,age):
        self.name = name
        self.age = age

 s1 = Student("srinidhi",19)
 print(s1.name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 6
#       3        self.name = name
#       4        self.age = age
# ----> 6 s1 = Student("srinidhi",19)
#       7 print(s1.name)
#
# NameError: name 'Student' is not defined

# %%
 class Student:
     def __init__(self,name,age):
        self.name = name
        self.age = age

 s1 = Student("srinidhi",19)
 print(s1.name)
# Out:
# srinidhi

# %%
  name="srinidhi"
  print(name)
# Out:
# srinidhi

# %%
name="srinidhi"
print(name)
email="srinidhi@gmail.com"
print(email)
# Out:
# srinidhi
# srinidhi@gmail.com

# %%
name="srinidhi"
print(name)
email="srinidhi@gmail.com"
print(email)

# %%
city="pune"
print(city[1])
# Out:
# u

# %%
city="peru"
print(city[0])
# Out:
# p

# %%
city="pune"
print(city[-1])
# Out:
# e

# %%
name="srinidhi"
print(name[1:7])
# Out:
# rinidh

# %%
name="srinidhi"
print(len(name))
# Out:
# 8

# %%
first="srinidhi"
second="goud"
print

# %%
print("Hello" * 3)
# Out:
# HelloHelloHello

# %%
name="srinidhi"
print(name.upper())
# Out:
# SRINIDHI

# %%
name="srinidhi"
print(name.lower())
# Out:
# srinidhi

# %%
s="I like Java"
print(s.replace("Java" , "Python"))
# Out:
# I like Python

# %%
s="anything something"
print(s.find("something"))
# Out:
# 9
